# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
winemag1 = pd.read_csv('../Python Folder/python-for-ds-course-master/winemag_150k.csv')

# %%
winemag1.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
winemag2 = pd.read_csv('../Python Folder/python-for-ds-course-master/winemag_130k.csv')

# %%
winemag2.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
winemag2= winemag2.drop(columns=['taster_name', 'taster_twitter_handle', 'title'])

# %%
winemag = pd.concat([winemag1, winemag2], axis=0)

# %%
winemag['value'] = winemag.points / winemag.price

# %%
winemag.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
winemag.loc[winemag['country'] == 'Albania']
# Out:
#       country                                        description designation  \
# 4642  Albania  This garnet-colored wine made from 100% Kallme...         NaN
# 4864  Albania  This garnet-colored wine made from 100% Kallme...         NaN
#
#       points  price province region_1 region_2  variety  winery  value
# 4642      88   20.0  Mirditë      NaN      NaN  Kallmet  Arbëri    4.4
# 4864      88   20.0  Mirditë      NaN      NaN  Kallmet  Arbëri    4.4

# %%
winemag.describe()
# Out:
#               points          price          value
# count  280901.000000  258210.000000  258210.000000
# mean       88.146934      34.177162       3.982419
# std         3.151528      38.611708       2.313636
# min        80.000000       4.000000       0.026667
# 25%        86.000000      16.000000       2.200000
# 50%        88.000000      25.000000       3.520000
# 75%        90.000000      40.000000       5.375000
# max       100.000000    3300.000000      21.500000

# %%
winemagscrub= winemag.dropna(subset = ['designation'])

# %%
winemagscrub.describe()
# Out:
#               points          price          value
# count  197701.000000  181120.000000  181120.000000
# mean       88.468966      36.576888       3.726743
# std         3.154242      36.227523       2.232650
# min        80.000000       4.000000       0.045206
# 25%        86.000000      18.000000       2.000000
# 50%        88.000000      28.000000       3.214286
# 75%        91.000000      45.000000       4.944444
# max       100.000000    2013.000000      21.500000

# %%
winemagscrub.groupby('country').agg({'designation':['count'],'points':['mean'], 'price':['mean']})
# Out:
#                        designation     points      price
#                              count       mean       mean
# country
# Argentina                     6838  86.738228  25.111735
# Armenia                          2  87.500000  14.500000
# Australia                     4987  88.578705  38.138883
# Austria                       5479  89.951268  32.740159
# Bosnia and Herzegovina           2  85.000000  13.000000
# Brazil                          69  84.420290  23.468750
# Bulgaria                       144  87.187500  14.729167
# Canada                         324  88.907407  40.015674
# Chile                         8796  86.570941  20.695917
# China                            2  85.500000  12.500000
# Croatia                        108  86.509259  25.640777
# Cyprus                          34  86.676471  16.088235
# Czech Republic                   7  88.142857  25.285714
# Egypt                            3  84.000000        NaN
# ...

# %%
winemagscrub.groupby('country').agg({'designation':['count'],'points':['max'], 'price':['max']})
# Out:
#                        designation points   price
#                              count    max     max
# country
# Argentina                     6838     97   250.0
# Armenia                          2     88    15.0
# Australia                     4987    100   850.0
# Austria                       5479     98  1100.0
# Bosnia and Herzegovina           2     85    13.0
# Brazil                          69     89    60.0
# Bulgaria                       144     91   100.0
# Canada                         324     94   145.0
# Chile                         8796     95   400.0
# China                            2     89    18.0
# Croatia                        108     91    65.0
# Cyprus                          34     89    22.0
# Czech Republic                   7     89    45.0
# Egypt                            3     84     NaN
# England                         83     95    95.0
# France                       29037    100  1400.0
# Georgia                        100     92    40.0
# ...

# %%
countrycontinent = pd.DataFrame({"country": ['Argentina', 'Armenia', 'Australia', 'Austria', 'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'China', 'Croatia', 'Cyprus', 'Czech Republic', 'Egypt', 'England', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'India', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Lithuania', 'Luxembourg', 'Macedonia', 'Mexico', 'Moldova', 'Morocco', 'New Zealand', 'Peru', 'Portugal', 'Romania', 'Serbia', 'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Switzerland', 'Tunisia', 'Turkey', 'US', 'Ukraine', 'Uruguay'],
                                    "continent": ['South America', 'Asia', 'Oceania', 'Europe', 'Europe', 'South America', 'Europe', 'North America', 'South America', 'Asia', 'Europe', 'Europe', 'Europe', 'Africa', 'Europe', 'Europe', 'Asia', 'Europe', 'Europe', 'Europe', 'Asia', 'Asia', 'Europe', 'Asia', 'Asia', 'Asia', 'Europe', 'Europe', 'North America', 'Europe', 'Africa' , 'Oceania', 'South America', 'Europe' , 'Europe', 'Europe', 'Europe', 'Africa', 'Asia', 'Europe', 'Europe', 'Africa', 'Asia', 'North America', 'Europe', 'South America']})

# %%
countrycontinent
# Out:
#                    country      continent
# 0                Argentina  South America
# 1                  Armenia           Asia
# 2                Australia        Oceania
# 3                  Austria         Europe
# 4   Bosnia and Herzegovina         Europe
# 5                   Brazil  South America
# 6                 Bulgaria         Europe
# 7                   Canada  North America
# 8                    Chile  South America
# 9                    China           Asia
# 10                 Croatia         Europe
# 11                  Cyprus         Europe
# 12          Czech Republic         Europe
# 13                   Egypt         Africa
# 14                 England         Europe
# 15                  France         Europe
# 16                 Georgia           Asia
# 17                 Germany         Europe
# 18                  Greece         Europe
# 19                 Hungary         Europe
# 20                   India           Asia
# ...

# %%
expandedwine = pd.merge(winemagscrub, countrycontinent, on='country', how='left')

# %%
expandedwine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
expandedwine.duplicated().sum()
# Out:
# 77604

# %%
expandedwine_nodup = expandedwine.drop_duplicates()

# %%
expandedwine_nodup.duplicated().sum()
# Out:
# 0

# %%
luxembourgwine
# Out:
#            country                                        description  \
# 46699   Luxembourg  Starts with aromas of minerals, pear and apple...
# 47572   Luxembourg  Offers aromas of honey, almond and white fruit...
# 47776   Luxembourg  A fresh but flirty nose of fresh white flowers...
# 107710  Luxembourg  This non vintage white blend is composed of 50...
# 138016  Luxembourg  This Riesling has white floral and lemon zest ...
# 139781  Luxembourg  This semisweet sparkling wine has vanilla bean...
# 161325  Luxembourg  Made from Auxerrois, this delightful white has...
# 185955  Luxembourg  This sparkling wine has vanilla bean, freshly ...
#
#                                         designation  points  price  \
# 46699          Domaine et Tradition Machtum Hohfels      88   50.0
# 47572                 Ahn Hohfels Grand Premier Cru      87   36.0
# 47776          Mertert Herrenberg Grand Premier Cru      86   36.0
# ...

# %%
expandedwine_nodup.groupby('continent').agg({'points':['mean'], 'price':['mean']})
# Out:
#                   points      price
#                     mean       mean
# continent
# Africa         88.252230  26.439570
# Asia           88.011628  30.324888
# Europe         88.724782  37.871870
# North America  88.782531  39.506629
# Oceania        88.559887  36.038797
# South America  86.668109  23.079701

# %%
expandedwine_nodup.groupby(['continent', 'country']).agg({'points':['mean'], 'price':['mean']},)
# Out:
#                                          points      price
#                                            mean       mean
# continent     country
# Africa        Egypt                   84.000000        NaN
#               Morocco                 88.533333  21.133333
#               South Africa            88.259473  26.511797
#               Tunisia                 86.000000        NaN
# Asia          Armenia                 87.500000  14.500000
#               China                   85.500000  12.500000
#               Georgia                 86.825397  19.174603
#               India                   89.600000  16.800000
#               Israel                  88.225490  32.451417
#               Japan                   85.000000  24.000000
#               Lebanon                 86.973684  31.789474
#               Lithuania               84.250000  10.000000
#               South Korea             81.500000  13.500000
#               Turkey                  88.573770  27.866667
# ...

# %%
luxembourgwine = expandedwine_nodup.loc[expandedwine_nodup['country'] == 'Luxembourg']

# %%
luxembourgwine.pivot(index='designation', columns='variety', values = 'price')
# Out:
# variety                                      Auxerrois  Pinot Gris  Riesling  \
# designation
# Ahn Hohfels Grand Premier Cru                      NaN        36.0       NaN
# Bech-Kleinmacher Naumberg Grand Premier Cru       22.0         NaN       NaN
# Cuvée Brut Crémant de Luxembourg                   NaN         NaN       NaN
# Domaine et Tradition Machtum Hohfels               NaN        50.0       NaN
# Mertert Herrenberg Grand Premier Cru               NaN         NaN      36.0
# Pinot Luxembourg                                   NaN         NaN       NaN
# Poll on Ice Crémant de Luxembourg Demi-Sec         NaN         NaN       NaN
# Wormeldange Weinbour Grand Premier Cru             NaN         NaN      23.0
#
# variety                                      Sparkling Blend  White Blend
# designation
# Ahn Hohfels Grand Premier Cru                            NaN          NaN
# Bech-Kleinmacher Naumberg Grand Premier Cru              NaN          NaN
# ...

# %%
southafricawine = expandedwine_nodup.loc[expandedwine_nodup['country'] == 'South Africa']

# %%
expandedwine_nodup.groupby('variety').agg({'points':['mean'], 'price':['mean'], 'value':['mean']})
# Out:
#                             points      price     value
#                               mean       mean      mean
# variety
# Abouriou                 86.000000  45.000000  3.466667
# Agiorgitiko              86.500000  23.716418  4.825791
# Aglianico                89.415205  40.535971  3.017160
# Aidani                   82.000000  27.000000  3.037037
# Airen                    81.000000   9.500000  8.544444
# Albana                   89.655172  25.653846  4.518276
# Albanello                86.000000  20.000000  4.300000
# Albariño                 87.715278  22.904255  4.386966
# Albarossa                88.000000  40.000000  2.200000
# Albarín                  84.000000  15.000000  5.600000
# Aleatico                 85.666667  36.000000  2.508398
# Alfrocheiro              88.909091  27.545455  4.057874
# Alicante                 87.142857  22.000000  4.499471
# Alicante Bouschet        89.288462  32.780000  4.249583
# Aligoté                  86.538462  18.307692  5.004015
# ...

# %%
sns.scatterplot(x='points',y='price', hue = 'continent', data=expandedwine_nodup);

# %%
sns.scatterplot(x='points',y='price', x_jitter=True, hue = 'continent', data=expandedwine_nodup);

# %%
northamericawine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'North America']

# %%
europewine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'Europe']

# %%
oceaniawine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'Oceania']

# %%
southamericawine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'South America']

# %%
asiawine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'Asia']

# %%
africawine = expandedwine_nodup.loc[expandedwine_nodup['continent'] == 'Africa']

# %%
southafricawine.groupby('province').agg({'value':['mean']},)
# Out:
#                             value
#                              mean
# province
# Bot River                2.421429
# Breedekloof              4.592593
# Cape Agulhas             3.540000
# Cape Peninsula           1.415385
# Cape South Coast              NaN
# Cederberg                3.093764
# Ceres Plateau                 NaN
# Coastal Region           5.322484
# Constantia               3.462154
# Darling                  3.423077
# Durbanville              3.732578
# Eilandia                 7.283333
# Elgin                    3.517060
# Elim                     3.137931
# Franschhoek              4.626732
# Groenekloof              2.093023
# Helderberg               2.485714
# Hemel en Aarde           1.636364
# Jonkershoek Valley       2.365066
# Klein River              5.000000
# Malgas                   2.571429
# Northern Cape            8.018182
# Olifants River           0.900000
# Overberg                 4.061786
# Paarl                    3.960989
# ...

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=northamericawine);

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=europewine);

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=oceaniawine);

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=asiawine);

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=africawine);

# %%
sns.scatterplot(x='points',y='price', hue = 'country', data=southamericawine);
